# %% [markdown]
# ## Pandas 공식문서에서 정한 Pandas Cheat Sheet
# - https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# ![Pandas_Cheat_Sheet_1.jpg](attachment:Pandas_Cheat_Sheet_1.jpg)

# %% [markdown]
# ![Pandas_Cheat_Sheet_2.jpg](attachment:Pandas_Cheat_Sheet_2.jpg)
